# %% [markdown]
# # Data cleaning
#
# By the end of the tutorials of this week, you should acquire:
#
# **Knowledge on:**
# * Inspection of dataframes
# * Identification and handling of missing values
# * Usage of functions to clean columns
# * Merging dataframes
#
# **Skills:**
# * .describe(), .dtypes
# * .isna().sum(), .fillna(), . dropna()
# * .apply() and selection of functions based on existing list
# * .merge()

# %%
import pandas as pd

# %% [markdown]
# ## Loading data

# %% [markdown]
# Instead of using Twitter data for this tutorial, I decided to use data from YouTube. I collected it using the [YouTube Data Tools](https://tools.digitalmethods.net/netvizz/youtube/), also created by the Digital Methods Initiative from the UvA.
#
# The data I have is from a video search using the keyword "climate change".
#
# It always helps if we note down what we want to do with the data *before* we start. We can always refine these objectives later.
#
# ### What do I want to achieve with this analysis?
#
# Ideally I have a few research questions here. While we won't be able to do the visualisations (which we will learn on week 4) or statistical testing (week 5 and 6), I am noting down some research questions that may be interesting.
#
# * RQ1. To what extent does the sentiment expressed in the title of the video influence user engagement (views, likes and dislikes)?
# * RQ2. To what extent does the sentiment expressed in the title of the video vary depending on the category in which the video is published?
# * RQ3. To what extent does the sentiment expressed in the title of the video vary depending on whether Greta Thunberg is mentioned?
#
# **Important:** I only want to do this for videos published in 2019 and 2020.
#
# These are examples - which are probably not very sophisticated yet as a business challenge - but they imply that we need a few things:
# 1. We need to have a sentiment analysis performed in the titles of the videos so we have the **sentiment** variable(s)
# 2. I need to make sure I have the user engagement variables (**likes**, **dislikes**, and **views**)
# 3. I need to have a variable for the **category** of the video
# 4. I need to know **when the video was published**, and remove old videos
# 5. I need to know if Greta is mentioned in the title
#
# With this noted down, I can start loading, inspecting and cleaning the data.

# %%
videos = pd.read_csv('videolist_search500_2020_01_25-12_34_16.tab')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-44-70a34e0eabd1> in <module>
# ----> 1 videos = pd.read_csv('videolist_search500_2020_01_25-12_34_16.tab')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     with parser:
# --> 463         return parser.read(nrows)
#     464
#     465
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1050     def read(self, nrows=None):
#    1051         nrows = validate_integer("nrows", nrows)
# -> 1052         index, columns, col_dict = self._engine.read(nrows)
#    1053
#    1054         if index is None:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2054     def read(self, nrows=None):
#    2055         try:
# -> 2056             data = self._reader.read(nrows)
#    2057         except StopIteration:
#    2058             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 4 fields in line 3, saw 6

# %% [markdown]
# Because this is a tab-delimited file (i.e., the separators are tabs, not commas), I need to specify this in the read_csv command.

# %%
videos = pd.read_csv('videolist_search500_2020_01_25-12_34_16.tab', sep='\t')

# %%
len(videos)

# %%
videos.head()

# %%
videos.columns

# %%
videos.describe()

# %%
videos.isna().sum()

# %% [markdown]
# *Some preliminary findings:*
# 1. It seems I have the engagement variables I need, but likeCount and dislikeCount seem to have missing values
# 2. I need to run sentiment analysis on videoTitle, but I don't seem to have a variable for language (so I cannot be sure if I just have titles in English)
# 3. The videoCategoryLabel column seems to be a starting point for the category variable.
# 4. The publishedAt column can probably help me filter videos from 2019 and 2020.
#
# All of this still needs to be confirmed though...

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Now let's start preparing the data. The steps always depend on the dataset, but at a minimum we need to make sure that we:
# 1. Handle the missing values for relevant variables
# 2. Check if the variables are stored in the correct format/type
# 3. Create the variables we need (that may be not in the data yet)

# %% [markdown]
# ### Missing values

# %%
videos.isna().sum()

# %% [markdown]
# From the variables I am interested in, seems like likeCount and dislikeCount are the ones that do have an issue. Let me check what's happening with them.
#
# One possibility would be that 0's are not included (i.e., if the video does not have a like, it will not appear). Let's see if that's the case...

# %%
videos[['likeCount', 'dislikeCount']].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b185e5e7c830> in <module>
# ----> 1 videos[['likeCount', 'dislikeCount']].describe()
#
# NameError: name 'videos' is not defined

# %% [markdown]
# The minimum value is 0, so probably something else is going on. Let's see if this is related to channels (e.g., some channels not allowing users to like videos, perhaps?).

# %%
videos[videos['likeCount'].isna()]['channelTitle'].value_counts()
#group by channel title and count the missing values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-db4e81ec8025> in <module>
# ----> 1 videos[videos['likeCount'].isna()]['channelTitle'].value_counts()
#       2 #group by channel title and count the missing values
#
# NameError: name 'videos' is not defined

# %% [markdown]
# OK, so here's the list of channels that have missing likes. Now let's see if they appear in a list of channels that have likes.
#
# First, let's make a list of all channels that do have likes and call it channels_with_likes.

# %%
channels_with_likes = videos[videos['likeCount'].isna()==False]['channelTitle'].unique().tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-48610a44201f> in <module>
# ----> 1 channels_with_likes = videos[videos['likeCount'].isna()==False]['channelTitle'].unique().tolist()
#
# NameError: name 'videos' is not defined

# %%
channels_with_likes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-45037be245ad> in <module>
# ----> 1 channels_with_likes
#
# NameError: name 'channels_with_likes' is not defined

# %% [markdown]
# Using "in" operator we can check if an element is present in a list.

# %%
'Intergovernmental Panel on Climate Change (IPCC)' in channels_with_likes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bd0094623e62> in <module>
# ----> 1 'Intergovernmental Panel on Climate Change (IPCC)' in channels_with_likes
#
# NameError: name 'channels_with_likes' is not defined

# %%
'The Lancet' in channels_with_likes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-547a6c7c8421> in <module>
# ----> 1 'The Lancet' in channels_with_likes
#
# NameError: name 'channels_with_likes' is not defined

# %% [markdown]
# This seems to be the case. But we cannot be very sure, so let's see how one of these video pages look like.

# %%
videos[videos['likeCount'].isna()]['videoId']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b0d8201e7c77> in <module>
# ----> 1 videos[videos['likeCount'].isna()]['videoId']
#
# NameError: name 'videos' is not defined

# %% [markdown]
# Let me add the YouTube URL to some of these id's and see what's going on there:
#
# * https://www.youtube.com/watch?v=9Nw5zhsSgHQ
# * https://www.youtube.com/watch?v=viZnvRnEvEc
# * https://www.youtube.com/watch?v=8_69vy7ZBxE
# * https://www.youtube.com/watch?v=NYstLwqtPlI

# %% [markdown]
# It seems that for most of them - but not all of them - the comments are turned off. But it does not necessarily mean that the missing values are always a specific number (e.g., a zero).
#
# Ultimately, I have generally two options with missing values:
# * I can substitute them by another value (e.g., 0)
# * I can drop them from the dataset

# %% [markdown]
# If I wanted to substitute them by another value, I would use the following command:

# %%
videos['dislikeCount_no_na'] = videos['dislikeCount'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5d6e435ac863> in <module>
# ----> 1 videos['dislikeCount_no_na'] = videos['dislikeCount'].fillna(0)
#
# NameError: name 'videos' is not defined

# %%
videos.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-5d26bcac41a9> in <module>
# ----> 1 videos.isna().sum()
#
# NameError: name 'videos' is not defined

# %% [markdown]
# But it doesn't seem to be appropriate here, as the number of likes for these videos is **not being informed** - sometimes because the channel does not allow comments, sometimes for other reasons. So it is a limitation (that we need to acknowledge in our reporting), but most likely dropping these values is better.
#
# To do so, I can run the following command:

# %%
videos = videos.dropna(subset=['likeCount', 'dislikeCount'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-afb42522085c> in <module>
# ----> 1 videos = videos.dropna(subset=['likeCount', 'dislikeCount'])
#
# NameError: name 'videos' is not defined

# %%
videos.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5d26bcac41a9> in <module>
# ----> 1 videos.isna().sum()
#
# NameError: name 'videos' is not defined

# %%
len(videos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f78b1eab10f7> in <module>
# ----> 1 len(videos)
#
# NameError: name 'videos' is not defined

# %% [markdown]
# ### Checking the data types
#
# It is also important to check if we have the data stored in the right format. Let's inspect it:

# %%
videos.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-cb7b55f13e0c> in <module>
# ----> 1 videos.dtypes
#
# NameError: name 'videos' is not defined

# %% [markdown]
# From my key variables so far (likeCount, dislikeCount, videoTitle, videoCategoryLabel), all looks OK. The numeric variables are in numeric form (int or float), and the text variables are in object form.
#
# But the date variable (publishedAt) is stored as an object... and it should be a date.

# %%
videos['publishedAt'].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6c24d9f35d33> in <module>
# ----> 1 videos['publishedAt'].head()
#
# NameError: name 'videos' is not defined

# %% [markdown]
# Yes, it looks like a date, but it is stored as an object. This is a problem, because I cannot filter the dataset by date.

# %%
videos['publishedAt'] = videos['publishedAt'].apply(pd.to_datetime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a45418e9b2c5> in <module>
# ----> 1 videos['publishedAt'] = videos['publishedAt'].apply(pd.to_datetime)
#
# NameError: name 'videos' is not defined

# %%
videos['publishedAt'].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6c24d9f35d33> in <module>
# ----> 1 videos['publishedAt'].head()
#
# NameError: name 'videos' is not defined

# %%
videos.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-cb7b55f13e0c> in <module>
# ----> 1 videos.dtypes
#
# NameError: name 'videos' is not defined

# %% [markdown]
# Now we can for example check the videos published in 2019 and 2020, for example:

# %%
videos[videos['publishedAt'] >'2018-12-31']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d77170fb248a> in <module>
# ----> 1 videos[videos['publishedAt'] >'2018-12-31']
#
# NameError: name 'videos' is not defined

# %% [markdown]
# Or I can get the oldest and the latest date for the videos:

# %%
videos['publishedAt'].min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f719b9bfcbdb> in <module>
# ----> 1 videos['publishedAt'].min()
#
# NameError: name 'videos' is not defined

# %%
videos['publishedAt'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-65b659f467cc> in <module>
# ----> 1 videos['publishedAt'].max()
#
# NameError: name 'videos' is not defined

# %%
len(videos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f78b1eab10f7> in <module>
# ----> 1 len(videos)
#
# NameError: name 'videos' is not defined

# %%
len(videos[videos['publishedAt'] >'2018-12-31'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6c79b613ae50> in <module>
# ----> 1 len(videos[videos['publishedAt'] >'2018-12-31'])
#
# NameError: name 'videos' is not defined

# %%
videos = videos[videos['publishedAt'] >'2018-12-31']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-fdc44d61be9a> in <module>
# ----> 1 videos = videos[videos['publishedAt'] >'2018-12-31']
#
# NameError: name 'videos' is not defined

# %% [markdown]
# ### Important!
#
# Above we have used the ```.apply``` method to run a function in that column. Curious about other things you can do with it? Check out the notebook "UsefulFunctions" in the "UsefulScripts" folder.

# %% [markdown]
# OK, just to recap, this is the status of the variables that we need:
# * Engagement: likeCount and dislikeCount are in the right type (int or float) and we fixed the missing values
# * Sentiment: the videoTitle column is in the right type (object), but we don't have sentiment yet
# * Category: we have the videoCategoryLabel, but we're not sure if it is really that informative yet
# * PublishedAt: we corrected the data type, and managed to slice the dataframe correctly. Yes!
# * Greta: we still need to check if she is mentioned in the title...

# %% [markdown]
# ## Requesting sentiment analysis
#
# As I don't have the language of the videos, I am going to use a Python module to automatically detect the language. It's available in the ```UsefulScripts``` folder, in the ```AdvancedModules``` notebook. If you want to use it, make sure to read the details in that notebook, as you may need to install a few things!

# %%
from langdetect import detect
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-9abb6c8b5db0> in <module>
# ----> 1 from langdetect import detect
#
# ModuleNotFoundError: No module named 'langdetect'

# %%
def apply_langdetect(text):
    text = str(text)
    try:
        lang = detect(text)
    except:
        lang = 'error'
        
    return lang

# %%
videos['lang_title'] = videos['videoTitle'].apply(apply_langdetect)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-30b2993cd204> in <module>
# ----> 1 videos['lang_title'] = videos['videoTitle'].apply(apply_langdetect)
#
# NameError: name 'videos' is not defined

# %%
videos['lang_title'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-19ee3b525757> in <module>
# ----> 1 videos['lang_title'].value_counts()
#
# NameError: name 'videos' is not defined

# %%
videos[videos['lang_title']!='en'][['lang_title', 'videoTitle']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0797ddc777dc> in <module>
# ----> 1 videos[videos['lang_title']!='en'][['lang_title', 'videoTitle']]
#
# NameError: name 'videos' is not defined

# %% [markdown]
# The language detection module doesn't seem to be working all the time. But it did identify a video with a Russian title. So we can safely remove that video, and make a judgement call of what to do with the rest.

# %%
videos = videos[videos['lang_title']!= 'ru']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-0d45ab266efb> in <module>
# ----> 1 videos = videos[videos['lang_title']!= 'ru']
#
# NameError: name 'videos' is not defined

# %%
len(videos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-f78b1eab10f7> in <module>
# ----> 1 len(videos)
#
# NameError: name 'videos' is not defined

# %% [markdown]
# Now I can export it for sentiment analysis. When doing so, I will also need to change the column name - from videoTitle to text -, otherwise the sentiment analysis script won't know what to do.

# %%
sent_export = videos[['videoId', 'videoTitle']].rename(columns={'videoTitle': 'text'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-ce773f79720b> in <module>
# ----> 1 sent_export = videos[['videoId', 'videoTitle']].rename(columns={'videoTitle': 'text'})
#
# NameError: name 'videos' is not defined

# %%
sent_export.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-a7045c9184dc> in <module>
# ----> 1 sent_export.head()
#
# NameError: name 'sent_export' is not defined

# %%
sent_export.to_pickle('TheoAraujo_YouTubeClimateChange_EN.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-1444486c07ea> in <module>
# ----> 1 sent_export.to_pickle('TheoAraujo_YouTubeClimateChange_EN.pkl')
#
# NameError: name 'sent_export' is not defined

# %% [markdown]
# Now I would usually upload this file to SurfDrive (see links in the homepage of the General Repository) and have to wait one or two workdays until the analysis is complete.
#
# When it is complete, I will find the file in the ```SentimentAnalysisResults``` folder also on SurfDrive. I have to download it and add to the same folder I am working on now.

# %%
sentiment = pd.read_pickle('TheoAraujo_YouTubeClimateChange_EN_completed.pkl')

# %%
sentiment.head()
# Out:
#        videoId                                               text negative  \
# 0  sGHq_EwXDn8  Australia’s Policies Going in Wrong Direction ...       -1
# 1  PRtn1W2RAVU  Nigel Farage compares President Trump and Prin...       -1
# 2  2CQvBGSiDvw  Climate change in the 2020s: What impacts to e...       -1
# 3  Cbwv1jg4gZU  Solution To Climate Change Is To Make It Profi...       -1
# 4  cWsCX_yxXqw   🌤 Climate Change from the Economic Point of View       -1
#
#   positive neutral
# 0        1       0
# 1        1       0
# 2        1       0
# 3        1       0
# 4        1       0

# %%
sentiment.dtypes
# Out:
# videoId     object
# text        object
# negative    object
# positive    object
# neutral     object
# dtype: object

# %%
sentiment.isna().sum()
# Out:
# videoId     0
# text        0
# negative    0
# positive    0
# neutral     0
# dtype: int64

# %% [markdown]
# ### Important tip!
#
# It seems I need to clean this variable (sentiment seems to be stored as an object). I will not show this in the video as this is part of the weekly challenge :-)
#
# *But I still need to merge the dataframes...*

# %% [markdown]
# ## Merging the dataframes
#
# Merging dataframes is an operation to bring the data of one dataframe into the other (or rather create a new dataframe). This is covered extensively in a video in the ```FAQs``` folder, and we will review it in class in a bit more detail (in DA3 and DA4).
#
# Basically, we need to use the command ```.merge```. A few important tips:
# * Make sure that you have one unique identifier (column) that is available in both dataframes
# * Make sure that the unique identifier column has the same name in both dataframes
# * Make sure that the unique identifier column is of the same data type in both dataframes

# %% [markdown]
# In our case, the unique identifier is videoId. Let's check the items above step by step:

# %%
videos.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-0b3d7b4b1874> in <module>
# ----> 1 videos.columns
#
# NameError: name 'videos' is not defined

# %%
sentiment.columns
# Out:
# Index(['videoId', 'text', 'negative', 'positive', 'neutral'], dtype='object')

# %%
videos.dtypes
# Out:
# position                            int64
# channelId                          object
# channelTitle                       object
# videoId                            object
# publishedAt           datetime64[ns, UTC]
# publishedAtSQL                     object
# videoTitle                         object
# videoDescription                   object
# videoCategoryId                     int64
# videoCategoryLabel                 object
# duration                           object
# durationSec                         int64
# dimension                          object
# definition                         object
# caption                              bool
# thumbnail_maxres                   object
# licensedContent                   float64
# viewCount                           int64
# likeCount                         float64
# dislikeCount                      float64
# favoriteCount                       int64
# commentCount                      float64
# lang_title                         object
# dtype: object

# %%
sentiment.dtypes
# Out:
# videoId     object
# text        object
# negative    object
# positive    object
# neutral     object
# dtype: object

# %% [markdown]
# OK, the column is available in both, and seems to be of the same data type. So I can merge.

# %%
len(videos)
# Out:
# 245

# %%
len(sentiment)
# Out:
# 244

# %%
videos.merge(sentiment, on='videoId')
# Out:
#      position                 channelId                        channelTitle  \
# 0           1  UCIALMKvObZNtJ6AmdCLP7Lg       Bloomberg Markets and Finance
# 1           2  UCb1Ti1WKPauPpXkYKVHNpsw                                 LBC
# 2           3  UC-SJ6nODDmufqBzPBwCvYvQ                    CBS This Morning
# 3           4  UCcyq283he07B7_KUX07mmtA                    Business Insider
# 4           5  UCWafKqurzE49MzZ6eHFwXvQ                           EconClips
# 5           6  UCIALMKvObZNtJ6AmdCLP7Lg       Bloomberg Markets and Finance
# 6           7  UCO0akufu9MOzyz3nvGIXAAw                  Sky News Australia
# 235  Greta Thunberg on the "gift" of Asperger's in ...
# 236  How climate change can leave children malnouri...
# 237  Piers Reacts to Greta Thunberg's UN Climate Su...
# 238  World leaders tackle climate change at COP25 s...
# 239                Top 5 Climate Change Myths Debunked
# 240  Piers Clashes With Extinction Rebellion Co-Lea...
# 241  Eldoret City Marathon themed "mitigating clima...
# 242          The Government Can't Solve Climate Change
# 243  HOW DARE YOU: 10 reasons not to believe climat...
#
#                                       videoDescription  videoCategoryId  \
# 0    Jan.23 -- Michael Mann, distinguished professo...               25
# 1    This is Nigel Farage's reaction to President T...               25
# 2    In our series The 2020's, we're exploring the ...               25
# 3    Environmental problems rose to the top of the ...               25
# 4    Climate change from the economic point of view...               27
# 5    Jan.22 -- Climate change and other environment...               25
# 6    Sky News host Chris Kenny says Al Gore and Pri...               25
# 7    U.S. President Donald Trump and climate activi...               25
# 8    Climate activist Greta Thunberg has told the D...               25
# 9    ABOVE AND BEYOND examines the role NASA plays ...               24
# 10   A new United Nations report warns the impacts ...               25
# 11   Former Australian PM, Malcolm Turnbull, argues...               25
# 12   Climate Change - Myth or Reality? Patrick Bet-...               27
# 13   What's the purpose of a company? Is it simply ...               25
# 14   Jan.21 -- Larry Fink, chief executive officer ...               25
# 15   Prince Charles, the heir to the British throne...               25
# 16   Following his speech on decarbonisation at the...               25
# 17   Jan.23 -- In this week’s “Commodity-In-Chief” ...               25
# 18   Donald Trump hit out at environmental "alarmis...               25
# 19   Greta Thunberg brought a stark message to the ...               25
# 20   Nigel Farage discusses the day's political eve...               25
# 21   17-year-old climate activist Greta Thunberg de...               25
# 22   Climate change is high on the global agenda. T...               25
# 23   President Trump answers a question on China at...               25
# 24   U.S. President Donald Trump decries "the peren...               25
# 25   NDTV is one of the leaders in the production a...               25
# 26   IMF chief economist Gita Gopinath has said the...               25
# 27   GRETA Thunberg addressed world leaders and CEO...               25
# 28   A new interactive map from researchers at the ...               28
# 29   Jan.21 -- Columbia University Professor Joseph...               25
# ..                                                 ...              ...
# 214  Thousands of firefighters have been battling w...               25
# 215  Bushfires are common during the summer in Aust...               25
# 216  While Americans are debating the authenticity ...               25
# 217  Sir David Attenborough has told this programme...               25
# 218  Hello all, Ive been working on this project fo...               22
# 219  On the 8th August 2019 the Intergovernmental P...               22
# 220  At 21, Benjamin Backer has a mission: get the ...               25
# 221  Entrepreneur Andrew Yang answers questions fro...               25
# 222                                                NaN               25
# 223  Democratic presidential candidate Bernie Sande...               24
# 224  Get 20% off a premium subscription to Brillian...               28
# 225  Hurricane Dorian continues to devastate the Ba...               25
# 226  What the Second World War was to our ancestors...               29
# 227  Forecasters predict an "above normal" hurrican...               25
# 228  July was Earth’s hottest month on record – eve...               25
# 229  Nov.21 -- Bill Gates, co-chair of the Bill & M...               25
# 230  Michael Killen, Dir. of the "Solutions that St...               22
# 231  I heard some bangin' and chantin' outside my h...               19
# 232  Dive into the world of aquaculture and see how...               27
# 233  After Hasan Minhaj questioned Justin Trudeau’s...               24
# 234  There have been urgent new warnings issued abo...               25
# 235  At 16, climate activist Greta Thunberg has bee...               25
# 236  Sumaiya’s moving story shows how climate chang...               29
# 237  16-year-old Greta Thunberg delivered a passion...               24
# 238  World leaders are meeting at a major climate s...               25
# 239  The top 5 myths and fallacies used to fuel cli...               22
# 240  There have been over 600 arrests since Monday ...               24
# 241  #NTVTonight #NTVKenya #NTVNews A rallying call...               25
# 242  Can politicians resolve major environmental is...               27
# 243  Famous for her hard-hitting video segments, Li...               29
#
#         videoCategoryLabel  ... viewCount  likeCount dislikeCount  \
# 0          News & Politics  ...      2017       31.0         24.0
# 1          News & Politics  ...     65633     1637.0        100.0
# 2          News & Politics  ...     34455      646.0         97.0
# 3          News & Politics  ...     24345      871.0         54.0
# 4                Education  ...      2085      129.0         23.0
# 5          News & Politics  ...      1053       22.0         12.0
# 6          News & Politics  ...     50699     2614.0         97.0
# 7          News & Politics  ...     48684      954.0        637.0
# 8          News & Politics  ...      9743      106.0        107.0
# 9            Entertainment  ...     32157     1122.0        139.0
# 10         News & Politics  ...    222477     2936.0       1529.0
# 11         News & Politics  ...      7690      135.0         45.0
# 12               Education  ...    162638     7103.0        608.0
# 13         News & Politics  ...      3615       86.0         20.0
# 14         News & Politics  ...      3003       36.0          6.0
# 15         News & Politics  ...     56956      837.0        190.0
# 16         News & Politics  ...     46630      695.0        257.0
# 17         News & Politics  ...       340        4.0          4.0
# 18         News & Politics  ...    302820     3837.0       1221.0
# 19         News & Politics  ...     14589      235.0        292.0
# 20         News & Politics  ...     40178      825.0         34.0
# 21         News & Politics  ...     41175      427.0       1109.0
# 22         News & Politics  ...     59345     1115.0        216.0
# 23         News & Politics  ...     77995      719.0       1183.0
# 24         News & Politics  ...     56696     3238.0        104.0
# 25         News & Politics  ...      1221       20.0          0.0
# 26         News & Politics  ...      4093       61.0         90.0
# 27         News & Politics  ...     30024      427.0        697.0
# 28    Science & Technology  ...    103422     2500.0        346.0
# 29         News & Politics  ...      5880       76.0         19.0
# ..                     ...  ...       ...        ...          ...
# 214        News & Politics  ...     23245      183.0         69.0
# 215        News & Politics  ...     57842      663.0        124.0
# 216        News & Politics  ...    148349     5912.0        258.0
# 217        News & Politics  ...     45461      877.0        141.0
# 218         People & Blogs  ...     61710     1223.0         36.0
# 219         People & Blogs  ...     25880     1780.0         69.0
# 220        News & Politics  ...      8897      195.0         76.0
# 221        News & Politics  ...    884726    29794.0       1030.0
# 222        News & Politics  ...      6519      108.0         31.0
# 223          Entertainment  ...    734838    17381.0        273.0
# 224   Science & Technology  ...    282714    11028.0        288.0
# 225        News & Politics  ...      8533      131.0         25.0
# 226  Nonprofits & Activism  ...      1401       38.0          6.0
# 227        News & Politics  ...     26974      536.0         42.0
# 228        News & Politics  ...     34419      421.0         29.0
# 229        News & Politics  ...    248894     3681.0        396.0
# 230         People & Blogs  ...       401       22.0          3.0
# 231        Travel & Events  ...        19        0.0          0.0
# 232              Education  ...    196478     8938.0        122.0
# 233          Entertainment  ...    241974     3264.0        233.0
# 234        News & Politics  ...     15103      256.0         14.0
# 235        News & Politics  ...    565507     7682.0       3268.0
# 236  Nonprofits & Activism  ...      2553       40.0          0.0
# 237          Entertainment  ...    782037     7534.0       7214.0
# 238        News & Politics  ...     18101      188.0        193.0
# 239         People & Blogs  ...     41065     3441.0        263.0
# 240          Entertainment  ...    946443    17005.0       2214.0
# 241        News & Politics  ...       170        1.0          0.0
# 242              Education  ...    619592    17725.0        846.0
# 243  Nonprofits & Activism  ...    550692    20821.0        702.0
#
#     favoriteCount  commentCount lang_title  \
# 0               0          57.0         en
# 1               0        1093.0         en
# 2               0         618.0         en
# 3               0         166.0         en
# 4               0          74.0         en
# 5               0           8.0         en
# 6               0        1979.0         en
# 7               0         925.0         en
# 8               0           NaN         en
# 9               0         659.0         en
# 10              0        3647.0         en
# 11              0         190.0         en
# 12              0        5599.0         en
# 13              0          76.0         en
# 14              0          17.0         en
# 15              0         779.0         en
# 16              0         351.0         en
# 17              0           1.0         en
# 18              0           0.0         en
# 19              0         363.0         en
# 20              0         336.0         en
# 21              0           0.0         en
# 22              0         470.0         en
# 23              0        1600.0         en
# 24              0        1159.0         en
# 25              0           5.0         en
# 26              0           NaN         en
# 27              0        1011.0         en
# 28              0         649.0         en
# 29              0          51.0         en
# ..            ...           ...        ...
# 214             0         115.0         en
# 215             0         775.0         en
# 216             0        1337.0         en
# 217             0         885.0         en
# 218             0         236.0         en
# 219             0         921.0         en
# 220             0         336.0         en
# 221             0       10162.0         en
# 222             0         103.0         en
# 223             0        2815.0         nl
# 224             0        1421.0         en
# 225             0         350.0         en
# 226             0          19.0         en
# 227             0         195.0         en
# 228             0         318.0         en
# 229             0        1317.0         en
# 230             0          10.0         en
# 231             0           0.0         en
# 232             0         404.0         en
# 233             0        1176.0         en
# 234             0         270.0         en
# 235             0        4273.0         en
# 236             0           5.0         en
# 237             0           NaN         en
# 238             0         695.0         en
# 239             0        1201.0         en
# 240             0           NaN         en
# 241             0           0.0         en
# 242             0        3493.0         en
# 243             0        6500.0         en
#
#                                                   text  negative  positive  \
# 0    Australia’s Policies Going in Wrong Direction ...        -1         1
# 1    Nigel Farage compares President Trump and Prin...        -1         1
# 2    Climate change in the 2020s: What impacts to e...        -1         1
# 3    Solution To Climate Change Is To Make It Profi...        -1         1
# 4     🌤 Climate Change from the Economic Point of View        -1         1
# 5    What Davos Attendees Are Saying on Climate Change        -1         1
# 6       Al Gore's 'climate change hypocrisy' is 'nuts'        -2         1
# 7    Trump vs Greta: How climate change took over D...        -1         1
# 8    Trump v Thunberg as two deliver contrasting cl...        -1         1
# 9    NASA's Research on Climate Change | Above and ...        -1         1
# 10   U.N. report warns on the impacts of climate ch...        -1         1
# 11   Australia fires: ‘We are in the frontline of c...        -1         1
# 12                   Climate Change - Myth or Reality?        -1         1
# 13   Davos 2020: Will capitalism tackle climate cha...        -2         1
# 14   BlackRock CEO Fink Sees Climate Change Becomin...        -1         1
# 15   UK's Prince Charles worries humanity has left ...        -4         1
# 16   Prince Charles Meets Greta Thunberg to Discuss...        -1         1
# 17   There is A Financial Convergence on Climate Ch...        -1         1
# [244 rows x 27 columns]

# %%
len(videos.merge(sentiment, on='videoId'))
# Out:
# 244

# %%
videos_sent = videos.merge(sentiment, on='videoId')

# %% [markdown]
# We are almost there. Let's recap where we are:
# * Engagement (OK): likeCount and dislikeCount are in the right type (int or float) and we fixed the missing values
# * Sentiment (OK-ish): we have the sentiment analysis results for the title, but they are in the wrong dtype. We won't fix it now - as you need to do it for the weekly challenge ;)
# * Category: we have the videoCategoryLabel, but we're not sure if it is really that informative yet
# * PublishedAt (OK): we corrected the data type, and managed to slice the dataframe correctly. Yes!
# * Greta: we still need to check if she is mentioned in the title...
#
# So we just need to work on the Category and mentions to Greta now.

# %% [markdown]
# ## Video Categories

# %%
videos_sent['videoCategoryLabel'].value_counts()
# Out:
# News & Politics          148
# Education                 26
# Science & Technology      21
# Entertainment             14
# Nonprofits & Activism     12
# Comedy                    10
# People & Blogs             9
# Autos & Vehicles           1
# Film & Animation           1
# Travel & Events            1
# Music                      1
# Name: videoCategoryLabel, dtype: int64

# %% [markdown]
# We have waaaay too many categories here to make informative comparisons, and some of them are very small (1 video), while others have a lot of videos. While we that will almost always be the case for digital trace data, we can at least recategorize this a bit...

# %%
def recategorize(category):
    if category == 'News & Politics':
        return category
    if category == 'Education':
        return 'Education, Science and Technology'
    if category == 'Science & Technology':
        return 'Education, Science and Technology'
    if category == 'Nonprofits & Activism':
        return category
    else:
        return 'Other'

# %%
videos_sent['category'] = videos_sent['videoCategoryLabel'].apply(recategorize)

# %%
videos_sent['category'].value_counts()
# Out:
# News & Politics                      148
# Other                                 37
# Education, Science and Technology     26
# Science & Technology                  21
# Nonprofits & Activism                 12
# Name: category, dtype: int64

# %% [markdown]
# This recategorization is not ideal, but at least we have five large(r) categories. One could argue that nonprofits is still too small. But for now we'll keep as is.

# %% [markdown]
# ## Mentions to Greta Thunberg
#
# I'll also use a function available in the ```UsefulFunctions``` notebook inside the ```UsefulScripts``` folder.

# %%
def wordlist_any_present(text, query):
    import re
    text = str(text).lower()
    newquery = []
    for word in query:
        newquery.append(str(word).lower())
    tokens = re.findall(r"[\w']+|[.,!?;$@#]", text)
    
    for word in newquery:
        if word in tokens:
            return 1
    return 0

# %%
videos_sent['Greta'] = videos_sent['videoTitle'].apply(wordlist_any_present, args=(['Greta', 'Thunberg'],))

# %%
videos_sent.groupby(['Greta'])['videoTitle'].value_counts()
# Out:
# Greta  videoTitle
# 0      'Alarmist rhetoric' on climate change not borne out by figures: Coalition backbencher                   1
#        'Climate warriors' use bushfires to push climate change inaction agenda: Credlin                        1
#        11,000 scientists sign declaration of climate emergency                                                 1
#        A Climate Change Sceptic Denies Global Warming Caused the Australian Fires | Good Morning Britain       1
#        A climate change solution that's right under our feet | Asmeret Asefaw Berhe:                           1
#        Al Gore Calls Climate Change the Most Serious Challenge Humanity Has Ever Faced                         1
#        Al Gore's 'climate change hypocrisy' is 'nuts'                                                          1
#        Amazon rainforest fires could devastate the fight against climate change                                1
#        Andrew Yang Talks Universal Basic Income, Climate Change, With Undecided Voters | Off Script | NPR      1
#        The disarming case to act right now on climate change | Greta Thunberg                                  1
#        Trump & Greta Thunberg clash on climate change in Davos | DW News                                       1
#        Trump and Greta Thunberg clash at Davos over climate change                                             1
#        Trump v Thunberg as two deliver contrasting climate change messages at Davos | ITV News                 1
#        Trump vs Greta: How climate change took over Davos | CNBC Reports                                       1
#        Trump, Greta Thunberg clash at Davos over climate change                                                1
#        Vladimir Putin criticises Greta Thunberg's UN speech on climate change - BBC News                       1
#        WATCH: Greta Thunberg's full speech to world leaders at UN Climate Action Summit                        1
# Name: videoTitle, Length: 244, dtype: int64

# %%
videos_sent['Greta'].value_counts()
# Out:
# 0    217
# 1     27
# Name: Greta, dtype: int64

# %% [markdown]
# Let's recap where we are:
# * Engagement (OK)
# * Sentiment (OK-ish): we have the sentiment analysis results for the title, but they are in the wrong dtype. We won't fix it now - as you need to do it for the weekly challenge ;)
# * Category (OK)
# * PublishedAt (OK)
# * Greta (OK)
#
# Great! Now let's just confirm that the dataframe looks OK.

# %%
videos_sent.columns
# Out:
# Index(['position', 'channelId', 'channelTitle', 'videoId', 'publishedAt',
#        'publishedAtSQL', 'videoTitle', 'videoDescription', 'videoCategoryId',
#        'videoCategoryLabel', 'duration', 'durationSec', 'dimension',
#        'definition', 'caption', 'thumbnail_maxres', 'licensedContent',
#        'viewCount', 'likeCount', 'dislikeCount', 'favoriteCount',
#        'commentCount', 'lang_title', 'text', 'negative', 'positive', 'neutral',
#        'category', 'Greta'],
#       dtype='object')

# %%
videos_sent.isna().sum()
# Out:
# position               0
# channelId              0
# channelTitle           0
# videoId                0
# publishedAt            0
# publishedAtSQL         0
# videoTitle             0
# videoDescription       1
# videoCategoryId        0
# videoCategoryLabel     0
# duration               0
# durationSec            0
# dimension              0
# definition             0
# caption                0
# thumbnail_maxres      39
# licensedContent       52
# viewCount              0
# likeCount              0
# dislikeCount           0
# favoriteCount          0
# commentCount          18
# lang_title             0
# text                   0
# negative               0
# positive               0
# neutral                0
# category               0
# Greta                  0
# dtype: int64

# %%
videos_sent.describe()
# Out:
#          position  videoCategoryId  durationSec  licensedContent  \
# count  244.000000       244.000000   244.000000            192.0
# mean   249.336066        25.139344   670.696721              1.0
# std    156.023983         2.855406   710.273139              0.0
# min      1.000000         1.000000    25.000000              1.0
# 25%    115.500000        25.000000   249.000000              1.0
# 50%    255.000000        25.000000   405.500000              1.0
# 75%    391.250000        25.000000   767.750000              1.0
# max    496.000000        29.000000  3574.000000              1.0
#
#           viewCount      likeCount   dislikeCount  favoriteCount  \
# count  2.440000e+02     244.000000     244.000000          244.0
# mean   2.088451e+05    5175.627049    1481.770492            0.0
# std    5.846930e+05   13847.417301    8989.718600            0.0
# min    1.900000e+01       0.000000       0.000000            0.0
# 25%    5.421250e+03     118.000000      22.750000            0.0
# 50%    3.270600e+04     678.000000     104.000000            0.0
# 75%    1.487812e+05    3430.500000     358.500000            0.0
# max    5.212827e+06  119562.000000  113733.000000            0.0
#
#        commentCount       Greta
# count    226.000000  244.000000
# mean    1895.008850    0.110656
# std     6754.155581    0.314350
# min        0.000000    0.000000
# 25%       71.000000    0.000000
# 50%      470.500000    0.000000
# 75%     1409.000000    0.000000
# max    88424.000000    1.000000

# %%
videos_sent['Greta'].value_counts()
# Out:
# 0    217
# 1     27
# Name: Greta, dtype: int64

# %%
videos_sent['Greta'].value_counts(normalize=True)
# Out:
# 0    0.889344
# 1    0.110656
# Name: Greta, dtype: float64

# %%
videos_sent['category'].value_counts()
# Out:
# News & Politics                      148
# Other                                 37
# Education, Science and Technology     26
# Science & Technology                  21
# Nonprofits & Activism                 12
# Name: category, dtype: int64

# %%
videos_sent['category'].value_counts(normalize=True)
# Out:
# News & Politics                      0.606557
# Other                                0.151639
# Education, Science and Technology    0.106557
# Science & Technology                 0.086066
# Nonprofits & Activism                0.049180
# Name: category, dtype: float64

# %% [markdown]
# ## We're done!
#
# ## But just because I am curious...
#
# Let's see quickly how engagement varies...

# %%
videos_sent.groupby('Greta')[['likeCount', 'dislikeCount', 'viewCount']].describe().transpose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf7d7aabdfb3> in <module>
# ----> 1 videos_sent.groupby('Greta')[['likeCount', 'dislikeCount', 'viewCount']].describe()
#
# NameError: name 'videos_sent' is not defined

# %% [markdown]
# Pandas is using scientific notation because of other columns being too large. So let's change this.

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
videos_sent.groupby('Greta')[['likeCount', 'dislikeCount', 'viewCount']].describe().transpose()
# Out:
# Greta                        0           1
# likeCount    count     217.000      27.000
#              mean     3023.512   22472.259
#              std      6855.640   32439.759
#              min         0.000       8.000
#              25%       104.000     448.500
#              50%       486.000    6594.000
#              75%      2614.000   39452.000
#              max     60703.000  119562.000
# dislikeCount count     217.000      27.000
#              mean      275.682   11175.148
#              std       596.279   25350.341
#              min         0.000       2.000
#              25%        20.000     667.000
#              50%        90.000    2894.000
#              75%       258.000    7849.500
#              max      6298.000  113733.000
# viewCount    count     217.000      27.000
#              mean   113961.111  971431.111
#              std    225297.503 1447203.335
#              min        19.000    1031.000
#              25%      4790.000   37986.000
#              50%     25880.000  393191.000
#              75%    101218.000  967080.000
#              max   1413077.000 5212827.000

# %%
videos_sent.groupby('category')[['likeCount', 'dislikeCount', 'viewCount']].mean().transpose()
# Out:
# category      Education, Science and Technology  News & Politics  \
# likeCount                              6042.115         3873.905
# dislikeCount                            588.154         1903.095
# viewCount                            156157.000       181584.791
#
# category      Nonprofits & Activism      Other  Science & Technology
# likeCount                  4083.000  10663.405              4232.286
# dislikeCount                107.500   1341.243               651.714
# viewCount                118376.500 415990.297            152924.333

# %%
videos_sent.groupby('category')[['likeCount', 'dislikeCount', 'viewCount']].std().transpose()
# Out:
# category      Education, Science and Technology  News & Politics  \
# likeCount                             12390.532        12182.607
# dislikeCount                           1286.850        11394.488
# viewCount                            276236.548       603834.274
#
# category      Nonprofits & Activism      Other  Science & Technology
# likeCount                  9107.242  21182.785             11083.051
# dislikeCount                212.598   3159.771              1819.082
# viewCount                253732.835 783798.953            374773.207

# %% [markdown]
# To make it more readable, you can use transpose (columns become rows, and vice-versa)

# %%
videos_sent.to_pickle('videos_sent.pkl')
